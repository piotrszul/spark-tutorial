# %% [markdown]
# http://spark.apache.org/docs/2.1.0/api/python/pyspark.sql.html#pyspark.sql.DataFrameReader

# %%
housingData = spark.read.csv('data/housing.csv', inferSchema = True, header = True, nullValue = 'NA' )

# %%
housingData.printSchema()
# Out:
# root
#  |-- fips: integer (nullable = true)
#  |-- county: string (nullable = true)
#  |-- state: string (nullable = true)
#  |-- time: timestamp (nullable = true)
#  |-- nSold: integer (nullable = true)
#  |-- medListPriceSqft: double (nullable = true)
#  |-- medSoldPriceSqft: double (nullable = true)

# %%
display(housingData)
# Out:
# DataFrame[fips: int, county: string, state: string, time: timestamp, nSold: int, medListPriceSqft: double, medSoldPriceSqft: double]
